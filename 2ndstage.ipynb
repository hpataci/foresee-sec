# %%
import os,sys,csv,urllib.request,time,re
from bs4 import BeautifulSoup   #<---- Need to install this package manually using pip

#os.chdir(r'C:\TestData\empissues_fromtempleU\py2files\testHilal2')#<===The location of your file "LongCompanyList.csv
IndexLinksFile = "IndexLinks.csv"  #a csv file (output of the 1GetIndexLinks.py script) with the list of index links for each firm (the file has a line with headers)
Form10kListFile = "10kList.csv"    #a csv file (output of the current script) with the list of 10-K links for each firm (the file has a line with headers)

def get10kLink(tickerCode, docIndex, docLink, description, filingDate, newFilingDate, FormType):
    csvOutput = open(Form10kListFile,"a")
    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)
    
    pageRequest = urllib.request.Request(docLink)
    pageOpen = urllib.request.urlopen(pageRequest)
    pageRead = pageOpen.read()
    
    soup = BeautifulSoup(pageRead,"html.parser")

    #Check if there is a table to extract / code exists in edgar database
    try:
        table = soup.find("table", { "summary" : "Document Format Files" })
    except:
        print("No tables found for link "+docLink)
        
    for row in table.findAll("tr"):
        cells = row.findAll("td")
        if len(cells)==5:
            if cells[3].text.strip() == FormType:
                link = cells[2].find("a")
                formLink = "https://www.sec.gov"+link['href']
                formName = link.text.strip()
                csvWriter.writerow([tickerCode, docIndex, docLink, description, filingDate, newFilingDate, formLink,formName])
    csvOutput.close()


def main():  
    FormType = "10-K"   ### <=== Type your document type here
    nbDocPause = 10 ### <=== Type your number of documents to download in one batch
    nbSecPause = 0.1 ### <=== Type your pausing time in seconds between each batch


    #csvOutput = open(Form10kListFile,"w") # delete the previous file
    #csvOutput.close()


    csvFile = open(IndexLinksFile,"r") #<===Open and read from a csv file with the list of index links for each firm (the file has a line with headers)
    csvReader = csv.reader(csvFile,delimiter=",")
    csvData = list(csvReader)
    
    csvOutput = open(Form10kListFile,"a") #<===open and write to a csv file which will include the list of 10-K links. New rows will be appended.
    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)
    
    csvWriter.writerow(["Ticker", "DocIndex", "IndexLink", "Description", "FilingDate", "NewFilingDate", "Form10KLink","Form10KName"])
    csvOutput.close()
    
    i = 1

    foundTicker = False
    
    for rowData in csvData[1:]:
        if(len(rowData)==0):
            continue
        

        Ticker = rowData[0]

    

        DocIndex = rowData[1]
        DocLink = rowData[2]
        Description = rowData[3]
        FileDate = rowData[4]
        NewFileDate = rowData[5]
        
        
        get10kLink(Ticker,DocIndex,DocLink,Description,FileDate,NewFileDate,FormType)
        if i%nbDocPause == 0:
            print(i)
            print("Pause for "+str(nbSecPause)+" second .... ")
            time.sleep(float(nbSecPause))
        i=i+1
       
    csvFile.close()
    print("done!")
    
if __name__ == "__main__":
	main()
# Out:
# 10
# Pause for 0.1 second ....
# 20
# Pause for 0.1 second ....
# 30
# Pause for 0.1 second ....
# 40
# Pause for 0.1 second ....
# 50
# Pause for 0.1 second ....
# 60
# Pause for 0.1 second ....
# 70
# Pause for 0.1 second ....
# 80
# Pause for 0.1 second ....
# 90
# Pause for 0.1 second ....
# 100
# Pause for 0.1 second ....
# 110
# Pause for 0.1 second ....
# 120
# Pause for 0.1 second ....
# 130
# Pause for 0.1 second ....
# 140
# Pause for 0.1 second ....
# 150
# Pause for 0.1 second ....
# 160
# Pause for 0.1 second ....
# 170
# Pause for 0.1 second ....
# 180
# Pause for 0.1 second ....
# 190
# Pause for 0.1 second ....
# 200
# Pause for 0.1 second ....
# 210
# Pause for 0.1 second ....
# 220
# Pause for 0.1 second ....
# 230
# Pause for 0.1 second ....
# 240
# Pause for 0.1 second ....
# 250
# Pause for 0.1 second ....
# 260
# Pause for 0.1 second ....
# 270
# Pause for 0.1 second ....
# 280
# Pause for 0.1 second ....
# 290
# Pause for 0.1 second ....
# 300
# Pause for 0.1 second ....
# 310
# Pause for 0.1 second ....
# 320
# Pause for 0.1 second ....
# 330
# Pause for 0.1 second ....
# 340
# Pause for 0.1 second ....
# 350
# Pause for 0.1 second ....
# 360
# Pause for 0.1 second ....
# 370
# Pause for 0.1 second ....
# 380
# Pause for 0.1 second ....
# 390
# Pause for 0.1 second ....
# 400
# Pause for 0.1 second ....
# 410
# Pause for 0.1 second ....
# 420
# Pause for 0.1 second ....
# 430
# Pause for 0.1 second ....
# 440
# Pause for 0.1 second ....
# 450
# Pause for 0.1 second ....
# 460
# Pause for 0.1 second ....
# 470
# Pause for 0.1 second ....
# 480
# Pause for 0.1 second ....
# 490
# Pause for 0.1 second ....
# 500
# Pause for 0.1 second ....
# 510
# Pause for 0.1 second ....
# 520
# Pause for 0.1 second ....
# 530
# Pause for 0.1 second ....
# 540
# Pause for 0.1 second ....
# 550
# Pause for 0.1 second ....
# 560
# Pause for 0.1 second ....
# 570
# Pause for 0.1 second ....
# 580
# Pause for 0.1 second ....
# 590
# Pause for 0.1 second ....
# 600
# Pause for 0.1 second ....
# 610
# Pause for 0.1 second ....
# 620
# Pause for 0.1 second ....
# 630
# Pause for 0.1 second ....
# 640
# Pause for 0.1 second ....
# 650
# Pause for 0.1 second ....
# 660
# Pause for 0.1 second ....
# 670
# Pause for 0.1 second ....
# 680
# Pause for 0.1 second ....
# 690
# Pause for 0.1 second ....
# 700
# Pause for 0.1 second ....
# 710
# Pause for 0.1 second ....
# 720
# Pause for 0.1 second ....
# 730
# Pause for 0.1 second ....
# 740
# Pause for 0.1 second ....
# 750
# Pause for 0.1 second ....
# 760
# Pause for 0.1 second ....
# 770
# Pause for 0.1 second ....
# 780
# Pause for 0.1 second ....
# 790
# Pause for 0.1 second ....
# 800
# Pause for 0.1 second ....
# 810
# Pause for 0.1 second ....
# 820
# Pause for 0.1 second ....
# 830
# Pause for 0.1 second ....
# 840
# Pause for 0.1 second ....
# 850
# Pause for 0.1 second ....
# 860
# Pause for 0.1 second ....
# 870
# Pause for 0.1 second ....
# 880
# Pause for 0.1 second ....
# 890
# Pause for 0.1 second ....
# 900
# Pause for 0.1 second ....
# 910
# Pause for 0.1 second ....
# 920
# Pause for 0.1 second ....
# 930
# Pause for 0.1 second ....
# 940
# Pause for 0.1 second ....
# 950
# Pause for 0.1 second ....
# 960
# Pause for 0.1 second ....
# 970
# Pause for 0.1 second ....
# 980
# Pause for 0.1 second ....
# 990
# Pause for 0.1 second ....
# 1000
# Pause for 0.1 second ....
# 1010
# Pause for 0.1 second ....
# 1020
# Pause for 0.1 second ....
# 1030
# Pause for 0.1 second ....
# 1040
# Pause for 0.1 second ....
# 1050
# Pause for 0.1 second ....
# 1060
# Pause for 0.1 second ....
# 1070
# Pause for 0.1 second ....
# 1080
# Pause for 0.1 second ....
# 1090
# Pause for 0.1 second ....
# 1100
# Pause for 0.1 second ....
# 1110
# Pause for 0.1 second ....
# 1120
# Pause for 0.1 second ....
# 1130
# Pause for 0.1 second ....
# 1140
# Pause for 0.1 second ....
# 1150
# Pause for 0.1 second ....
# 1160
# Pause for 0.1 second ....
# 1170
# Pause for 0.1 second ....
# 1180
# Pause for 0.1 second ....
# 1190
# Pause for 0.1 second ....
# 1200
# Pause for 0.1 second ....
# 1210
# Pause for 0.1 second ....
# 1220
# Pause for 0.1 second ....
# 1230
# Pause for 0.1 second ....
# 1240
# Pause for 0.1 second ....
# 1250
# Pause for 0.1 second ....
# 1260
# Pause for 0.1 second ....
# 1270
# Pause for 0.1 second ....
# 1280
# Pause for 0.1 second ....
# 1290
# Pause for 0.1 second ....
# 1300
# Pause for 0.1 second ....
# 1310
# Pause for 0.1 second ....
# 1320
# Pause for 0.1 second ....
# 1330
# Pause for 0.1 second ....
# 1340
# Pause for 0.1 second ....
# 1350
# Pause for 0.1 second ....
# 1360
# Pause for 0.1 second ....
# 1370
# Pause for 0.1 second ....
# 1380
# Pause for 0.1 second ....
# 1390
# Pause for 0.1 second ....
# 1400
# Pause for 0.1 second ....
# 1410
# Pause for 0.1 second ....
# 1420
# Pause for 0.1 second ....
# 1430
# Pause for 0.1 second ....
# 1440
# Pause for 0.1 second ....
# 1450
# Pause for 0.1 second ....
# 1460
# Pause for 0.1 second ....
# 1470
# Pause for 0.1 second ....
# 1480
# Pause for 0.1 second ....
# 1490
# Pause for 0.1 second ....
# 1500
# Pause for 0.1 second ....
# 1510
# Pause for 0.1 second ....
# 1520
# Pause for 0.1 second ....
# 1530
# Pause for 0.1 second ....
# 1540
# Pause for 0.1 second ....
# 1550
# Pause for 0.1 second ....
# 1560
# Pause for 0.1 second ....
# 1570
# Pause for 0.1 second ....
# 1580
# Pause for 0.1 second ....
# 1590
# Pause for 0.1 second ....
# 1600
# Pause for 0.1 second ....
# 1610
# Pause for 0.1 second ....
# 1620
# Pause for 0.1 second ....
# 1630
# Pause for 0.1 second ....
# 1640
# Pause for 0.1 second ....
# 1650
# Pause for 0.1 second ....
# 1660
# Pause for 0.1 second ....
# 1670
# Pause for 0.1 second ....
# 1680
# Pause for 0.1 second ....
# 1690
# Pause for 0.1 second ....
# 1700
# Pause for 0.1 second ....
# 1710
# Pause for 0.1 second ....
# 1720
# Pause for 0.1 second ....
# 1730
# Pause for 0.1 second ....
# 1740
# Pause for 0.1 second ....
# 1750
# Pause for 0.1 second ....
# 1760
# Pause for 0.1 second ....
# 1770
# Pause for 0.1 second ....
# 1780
# Pause for 0.1 second ....
# 1790
# Pause for 0.1 second ....
# 1800
# Pause for 0.1 second ....
# 1810
# Pause for 0.1 second ....
# 1820
# Pause for 0.1 second ....
# 1830
# Pause for 0.1 second ....
# 1840
# Pause for 0.1 second ....
# 1850
# Pause for 0.1 second ....
# 1860
# Pause for 0.1 second ....
# 1870
# Pause for 0.1 second ....
# 1880
# Pause for 0.1 second ....
# 1890
# Pause for 0.1 second ....
# 1900
# Pause for 0.1 second ....
# 1910
# Pause for 0.1 second ....
# 1920
# Pause for 0.1 second ....
# 1930
# Pause for 0.1 second ....
# 1940
# Pause for 0.1 second ....
# 1950
# Pause for 0.1 second ....
# 1960
# Pause for 0.1 second ....
# 1970
# Pause for 0.1 second ....
# 1980
# Pause for 0.1 second ....
# 1990
# Pause for 0.1 second ....
# 2000
# Pause for 0.1 second ....
# 2010
# Pause for 0.1 second ....
# 2020
# Pause for 0.1 second ....
# 2030
# Pause for 0.1 second ....
# 2040
# Pause for 0.1 second ....
# 2050
# Pause for 0.1 second ....
# 2060
# Pause for 0.1 second ....
# 2070
# Pause for 0.1 second ....
# 2080
# Pause for 0.1 second ....
# 2090
# Pause for 0.1 second ....
# 2100
# Pause for 0.1 second ....
# 2110
# Pause for 0.1 second ....
# 2120
# Pause for 0.1 second ....
# 2130
# Pause for 0.1 second ....
# 2140
# Pause for 0.1 second ....
# 2150
# Pause for 0.1 second ....
# 2160
# Pause for 0.1 second ....
# 2170
# Pause for 0.1 second ....
# 2180
# Pause for 0.1 second ....
# 2190
# Pause for 0.1 second ....
# 2200
# Pause for 0.1 second ....
# 2210
# Pause for 0.1 second ....
# 2220
# Pause for 0.1 second ....
# 2230
# Pause for 0.1 second ....
# 2240
# Pause for 0.1 second ....
# 2250
# Pause for 0.1 second ....
# 2260
# Pause for 0.1 second ....
# 2270
# Pause for 0.1 second ....
# 2280
# Pause for 0.1 second ....
# 2290
# Pause for 0.1 second ....
# 2300
# Pause for 0.1 second ....
# 2310
# Pause for 0.1 second ....
# 2320
# Pause for 0.1 second ....
# 2330
# Pause for 0.1 second ....
# 2340
# Pause for 0.1 second ....
# 2350
# Pause for 0.1 second ....
# 2360
# Pause for 0.1 second ....
# 2370
# Pause for 0.1 second ....
# 2380
# Pause for 0.1 second ....
# 2390
# Pause for 0.1 second ....
# 2400
# Pause for 0.1 second ....
# 2410
# Pause for 0.1 second ....
# 2420
# Pause for 0.1 second ....
# 2430
# Pause for 0.1 second ....
# 2440
# Pause for 0.1 second ....
# 2450
# Pause for 0.1 second ....
# 2460
# Pause for 0.1 second ....
# 2470
# Pause for 0.1 second ....
# 2480
# Pause for 0.1 second ....
# 2490
# Pause for 0.1 second ....
# 2500
# Pause for 0.1 second ....
# 2510
# Pause for 0.1 second ....
# 2520
# Pause for 0.1 second ....
# 2530
# Pause for 0.1 second ....
# 2540
# Pause for 0.1 second ....
# 2550
# Pause for 0.1 second ....
# 2560
# Pause for 0.1 second ....
# 2570
# Pause for 0.1 second ....
# 2580
# Pause for 0.1 second ....
# 2590
# Pause for 0.1 second ....
# 2600
# Pause for 0.1 second ....
# 2610
# Pause for 0.1 second ....
# 2620
# Pause for 0.1 second ....
# 2630
# Pause for 0.1 second ....
# 2640
# Pause for 0.1 second ....
# 2650
# Pause for 0.1 second ....
# 2660
# Pause for 0.1 second ....
# 2670
# Pause for 0.1 second ....
# 2680
# Pause for 0.1 second ....
# 2690
# Pause for 0.1 second ....
# 2700
# Pause for 0.1 second ....
# 2710
# Pause for 0.1 second ....
# 2720
# Pause for 0.1 second ....
# 2730
# Pause for 0.1 second ....
# 2740
# Pause for 0.1 second ....
# 2750
# Pause for 0.1 second ....
# 2760
# Pause for 0.1 second ....
# 2770
# Pause for 0.1 second ....
# 2780
# Pause for 0.1 second ....
# 2790
# Pause for 0.1 second ....
# 2800
# Pause for 0.1 second ....
# 2810
# Pause for 0.1 second ....
# 2820
# Pause for 0.1 second ....
# 2830
# Pause for 0.1 second ....
# 2840
# Pause for 0.1 second ....
# 2850
# Pause for 0.1 second ....
# 2860
# Pause for 0.1 second ....
# 2870
# Pause for 0.1 second ....
# 2880
# Pause for 0.1 second ....
# 2890
# Pause for 0.1 second ....
# 2900
# Pause for 0.1 second ....
# 2910
# Pause for 0.1 second ....
# 2920
# Pause for 0.1 second ....
# 2930
# Pause for 0.1 second ....
# 2940
# Pause for 0.1 second ....
# 2950
# Pause for 0.1 second ....
# 2960
# Pause for 0.1 second ....
# 2970
# Pause for 0.1 second ....
# 2980
# Pause for 0.1 second ....
# 2990
# Pause for 0.1 second ....
# 3000
# Pause for 0.1 second ....
# 3010
# Pause for 0.1 second ....
# 3020
# Pause for 0.1 second ....
# 3030
# Pause for 0.1 second ....
# 3040
# Pause for 0.1 second ....
# 3050
# Pause for 0.1 second ....
# 3060
# Pause for 0.1 second ....
# 3070
# Pause for 0.1 second ....
# 3080
# Pause for 0.1 second ....
# 3090
# Pause for 0.1 second ....
# 3100
# Pause for 0.1 second ....
# 3110
# Pause for 0.1 second ....
# 3120
# Pause for 0.1 second ....
# 3130
# Pause for 0.1 second ....
# 3140
# Pause for 0.1 second ....
# 3150
# Pause for 0.1 second ....
# 3160
# Pause for 0.1 second ....
# 3170
# Pause for 0.1 second ....
# 3180
# Pause for 0.1 second ....
# 3190
# Pause for 0.1 second ....
# 3200
# Pause for 0.1 second ....
# 3210
# Pause for 0.1 second ....
# 3220
# Pause for 0.1 second ....
# 3230
# Pause for 0.1 second ....
# 3240
# Pause for 0.1 second ....
# 3250
# Pause for 0.1 second ....
# 3260
# Pause for 0.1 second ....
# 3270
# Pause for 0.1 second ....
# 3280
# Pause for 0.1 second ....
# 3290
# Pause for 0.1 second ....
# 3300
# Pause for 0.1 second ....
# 3310
# Pause for 0.1 second ....
# 3320
# Pause for 0.1 second ....
# 3330
# Pause for 0.1 second ....
# 3340
# Pause for 0.1 second ....
# 3350
# Pause for 0.1 second ....
# 3360
# Pause for 0.1 second ....
# 3370
# Pause for 0.1 second ....
# 3380
# Pause for 0.1 second ....
# 3390
# Pause for 0.1 second ....
# 3400
# Pause for 0.1 second ....
# 3410
# Pause for 0.1 second ....
# 3420
# Pause for 0.1 second ....
# 3430
# Pause for 0.1 second ....
# 3440
# Pause for 0.1 second ....
# 3450
# Pause for 0.1 second ....
# 3460
# Pause for 0.1 second ....
# 3470
# Pause for 0.1 second ....
# 3480
# Pause for 0.1 second ....
# 3490
# Pause for 0.1 second ....
# 3500
# Pause for 0.1 second ....
# 3510
# Pause for 0.1 second ....
# 3520
# Pause for 0.1 second ....
# 3530
# Pause for 0.1 second ....
# 3540
# Pause for 0.1 second ....
# 3550
# Pause for 0.1 second ....
# 3560
# Pause for 0.1 second ....
# 3570
# Pause for 0.1 second ....
# 3580
# Pause for 0.1 second ....
# 3590
# Pause for 0.1 second ....
# 3600
# Pause for 0.1 second ....
# 3610
# Pause for 0.1 second ....
# 3620
# Pause for 0.1 second ....
# 3630
# Pause for 0.1 second ....
# 3640
# Pause for 0.1 second ....
# 3650
# Pause for 0.1 second ....
# 3660
# Pause for 0.1 second ....
# 3670
# Pause for 0.1 second ....
# 3680
# Pause for 0.1 second ....
# 3690
# Pause for 0.1 second ....
# 3700
# Pause for 0.1 second ....
# 3710
# Pause for 0.1 second ....
# 3720
# Pause for 0.1 second ....
# 3730
# Pause for 0.1 second ....
# 3740
# Pause for 0.1 second ....
# 3750
# Pause for 0.1 second ....
# 3760
# Pause for 0.1 second ....
# 3770
# Pause for 0.1 second ....
# 3780
# Pause for 0.1 second ....
# 3790
# Pause for 0.1 second ....
# 3800
# Pause for 0.1 second ....
# 3810
# Pause for 0.1 second ....
# 3820
# Pause for 0.1 second ....
# 3830
# Pause for 0.1 second ....
# 3840
# Pause for 0.1 second ....
# 3850
# Pause for 0.1 second ....
# 3860
# Pause for 0.1 second ....
# 3870
# Pause for 0.1 second ....
# 3880
# Pause for 0.1 second ....
# 3890
# Pause for 0.1 second ....
# 3900
# Pause for 0.1 second ....
# 3910
# Pause for 0.1 second ....
# 3920
# Pause for 0.1 second ....
# 3930
# Pause for 0.1 second ....
# 3940
# Pause for 0.1 second ....
# 3950
# Pause for 0.1 second ....
# 3960
# Pause for 0.1 second ....
# 3970
# Pause for 0.1 second ....
# 3980
# Pause for 0.1 second ....
# 3990
# Pause for 0.1 second ....
# 4000
# Pause for 0.1 second ....
# 4010
# Pause for 0.1 second ....
# 4020
# Pause for 0.1 second ....
# 4030
# Pause for 0.1 second ....
# 4040
# Pause for 0.1 second ....
# 4050
# Pause for 0.1 second ....
# 4060
# Pause for 0.1 second ....
# 4070
# Pause for 0.1 second ....
# 4080
# Pause for 0.1 second ....
# 4090
# Pause for 0.1 second ....
# 4100
# Pause for 0.1 second ....
# 4110
# Pause for 0.1 second ....
# 4120
# Pause for 0.1 second ....
# 4130
# Pause for 0.1 second ....
# 4140
# Pause for 0.1 second ....
# 4150
# Pause for 0.1 second ....
# 4160
# Pause for 0.1 second ....
# 4170
# Pause for 0.1 second ....
# 4180
# Pause for 0.1 second ....
# 4190
# Pause for 0.1 second ....
# 4200
# Pause for 0.1 second ....
# 4210
# Pause for 0.1 second ....
# 4220
# Pause for 0.1 second ....
# 4230
# Pause for 0.1 second ....
# 4240
# Pause for 0.1 second ....
# 4250
# Pause for 0.1 second ....
# 4260
# Pause for 0.1 second ....
# 4270
# Pause for 0.1 second ....
# 4280
# Pause for 0.1 second ....
# 4290
# Pause for 0.1 second ....
# 4300
# Pause for 0.1 second ....
# 4310
# Pause for 0.1 second ....
# 4320
# Pause for 0.1 second ....
# 4330
# Pause for 0.1 second ....
# 4340
# Pause for 0.1 second ....
# 4350
# Pause for 0.1 second ....
# 4360
# Pause for 0.1 second ....
# 4370
# Pause for 0.1 second ....
# 4380
# Pause for 0.1 second ....
# 4390
# Pause for 0.1 second ....
# 4400
# Pause for 0.1 second ....
# 4410
# Pause for 0.1 second ....
# 4420
# Pause for 0.1 second ....
# 4430
# Pause for 0.1 second ....
# 4440
# Pause for 0.1 second ....
# 4450
# Pause for 0.1 second ....
# 4460
# Pause for 0.1 second ....
# 4470
# Pause for 0.1 second ....
# 4480
# Pause for 0.1 second ....
# 4490
# Pause for 0.1 second ....
# 4500
# Pause for 0.1 second ....
# 4510
# Pause for 0.1 second ....
# 4520
# Pause for 0.1 second ....
# 4530
# Pause for 0.1 second ....
# 4540
# Pause for 0.1 second ....
# 4550
# Pause for 0.1 second ....
# 4560
# Pause for 0.1 second ....
# 4570
# Pause for 0.1 second ....
# 4580
# Pause for 0.1 second ....
# 4590
# Pause for 0.1 second ....
# 4600
# Pause for 0.1 second ....
# 4610
# Pause for 0.1 second ....
# 4620
# Pause for 0.1 second ....
# 4630
# Pause for 0.1 second ....
# 4640
# Pause for 0.1 second ....
# 4650
# Pause for 0.1 second ....
# 4660
# Pause for 0.1 second ....
# 4670
# Pause for 0.1 second ....
# 4680
# Pause for 0.1 second ....
# 4690
# Pause for 0.1 second ....
# 4700
# Pause for 0.1 second ....
# 4710
# Pause for 0.1 second ....
# 4720
# Pause for 0.1 second ....
# 4730
# Pause for 0.1 second ....
# 4740
# Pause for 0.1 second ....
# 4750
# Pause for 0.1 second ....
# 4760
# Pause for 0.1 second ....
# 4770
# Pause for 0.1 second ....
# 4780
# Pause for 0.1 second ....
# 4790
# Pause for 0.1 second ....
# 4800
# Pause for 0.1 second ....
# 4810
# Pause for 0.1 second ....
# 4820
# Pause for 0.1 second ....
# 4830
# Pause for 0.1 second ....
# 4840
# Pause for 0.1 second ....
# 4850
# Pause for 0.1 second ....
# 4860
# Pause for 0.1 second ....
# 4870
# Pause for 0.1 second ....
# 4880
# Pause for 0.1 second ....
# 4890
# Pause for 0.1 second ....
# 4900
# Pause for 0.1 second ....
# 4910
# Pause for 0.1 second ....
# 4920
# Pause for 0.1 second ....
# 4930
# Pause for 0.1 second ....
# 4940
# Pause for 0.1 second ....
# 4950
# Pause for 0.1 second ....
# 4960
# Pause for 0.1 second ....
# 4970
# Pause for 0.1 second ....
# 4980
# Pause for 0.1 second ....
# 4990
# Pause for 0.1 second ....
# 5000
# Pause for 0.1 second ....
# 5010
# Pause for 0.1 second ....
# 5020
# Pause for 0.1 second ....
# 5030
# Pause for 0.1 second ....
# 5040
# Pause for 0.1 second ....
# 5050
# Pause for 0.1 second ....
# 5060
# Pause for 0.1 second ....
# 5070
# Pause for 0.1 second ....
# done!
