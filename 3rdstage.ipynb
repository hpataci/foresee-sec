# %%
#coding:utf8
import os,sys,csv,urllib.request,time

#os.chdir(r'C:\TestData\empissues_fromtempleU\py2files\testHilal2') #<===location of your "CompanyList.csv"
htmlSubPath = "HTML2" #<===subdir with HTML 10Ks

Form10kListFile = "10kList.csv" #a csv file (output of the 2Get10kLinks.py script) with the list of 10-K links
logFile = "10kDownloadLog.csv" #a csv file (output of the current script) with the download history of 10-K forms

def download10k(tickerCode, docIndex, docLink, description, filingDate, newFilingDate, formLink,formName):
    csvOutput = open(logFile,"a")
    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)

    try:
        pageRequest = urllib.request.Request(formLink)
        pageOpen = urllib.request.urlopen(pageRequest)
        pageRead = pageOpen.read()

        #print(pageRead)
        htmlname = tickerCode+"_"+docIndex+"_"+newFilingDate+".htm"
        #htmlpath = htmlSubPath + "\" + htmlname
        htmlpath = os.path.join(os.getcwd(),htmlSubPath, htmlname)
        #print(htmlpath)

        htmlfile = open(htmlpath,"w")
        #print(htmlfile)

        htmlfile.write(pageRead.decode("utf-8"))
        htmlfile.close()
        csvWriter.writerow([tickerCode, docIndex, docLink, description, filingDate, newFilingDate, formLink,formName, htmlname, ""])
    except Exception as inst:
        csvWriter.writerow([tickerCode, docIndex, docLink, description, filingDate, newFilingDate, formLink,formName, "","not downloaded"])
        print("Unexpected error:", inst)

    csvOutput.close()

def main():
    if not os.path.isdir(htmlSubPath):  ### <=== keep all HTML files in this subfolder
        os.makedirs(htmlSubPath)
    
    FormType = "10-K"   ### <=== Type your document type here
    nbDocPause = 25 ### <=== Type your number of documents to download in one batch
    nbSecPause = 1 ### <=== Type your pausing time in seconds between each batch

    FormYears = []
    formYears = []

    for i in range(2010,2021):
        formYears.append(str(i))
  
    FormYears = formYears
    
    #FormYears = ['2014','2015'] ### <=== Type the years of documents to download here

    csvFile = open(Form10kListFile,"r") #<===A csv file with the list of company ticker symbols (the file has a line with headers)
    csvReader = csv.reader(csvFile,delimiter=",")
    csvData = list(csvReader)

    csvOutput = open(logFile,"a")
    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)

    csvWriter.writerow(["Ticker", "DocIndex", "IndexLink", "Description", "FilingDate", "NewFilingDate", "Form10KLink", "Form10KName", "FileName", "Note"])
    csvOutput.close()
    
    i = 1
    for rowData in csvData[1:]:
        Ticker = rowData[0]
        DocIndex = rowData[1]
        IndexLink = rowData[2]
        Description = rowData[3]
        FilingDate = rowData[4]
        NewFilingDate = rowData[5]
        FormLink = rowData[6]
        FormName = rowData[7]
        for year in FormYears:
            if year in FilingDate:
                if ".htm" in FormName:
                    download10k(Ticker, DocIndex, IndexLink, Description, FilingDate, NewFilingDate, FormLink, FormName)
                elif ".txt" in FormName:
                    csvOutput = open(logFile,"a")
                    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)
                    csvWriter.writerow([Ticker, DocIndex, IndexLink, Description, FilingDate, NewFilingDate, FormLink, FormName, "", "Text format"])
                    csvOutput.close()
                else:
                    csvOutput = open(logFile,"a")
                    csvWriter = csv.writer(csvOutput, quoting = csv.QUOTE_NONNUMERIC)
                    csvWriter.writerow([Ticker, DocIndex, IndexLink, Description, FilingDate, NewFilingDate, FormLink, FormName, "", "No form"])
                    csvOutput.close()
            
        if i%nbDocPause == 0:
            print(i)
            print("Pause for "+str(nbSecPause)+" second .... ")
            time.sleep(float(nbSecPause))
        i=i+1
       
    csvFile.close()
    print("done!")
    
if __name__ == "__main__":
	main()
# Out:
# 25
# Pause for 1 second ....
# 50
# Pause for 1 second ....
# 75
# Pause for 1 second ....
# 100
# Pause for 1 second ....
# 125
# Pause for 1 second ....
# 150
# Pause for 1 second ....
# 175
# Pause for 1 second ....
# 200
# Pause for 1 second ....
# 225
# Pause for 1 second ....
# 250
# Pause for 1 second ....
# 275
# Pause for 1 second ....
# 300
# Pause for 1 second ....
# 325
# Pause for 1 second ....
# 350
# Pause for 1 second ....
# 375
# Pause for 1 second ....
# 400
# Pause for 1 second ....
# 425
# Pause for 1 second ....
# 450
# Pause for 1 second ....
# 475
# Pause for 1 second ....
# 500
# Pause for 1 second ....
# 525
# Pause for 1 second ....
# 550
# Pause for 1 second ....
# 575
# Pause for 1 second ....
# 600
# Pause for 1 second ....
# 625
# Pause for 1 second ....
# 650
# Pause for 1 second ....
# 675
# Pause for 1 second ....
# 700
# Pause for 1 second ....
# 725
# Pause for 1 second ....
# 750
# Pause for 1 second ....
# 775
# Pause for 1 second ....
# 800
# Pause for 1 second ....
# 825
# Pause for 1 second ....
# 850
# Pause for 1 second ....
# 875
# Pause for 1 second ....
# 900
# Pause for 1 second ....
# 925
# Pause for 1 second ....
# 950
# Pause for 1 second ....
# 975
# Pause for 1 second ....
# 1000
# Pause for 1 second ....
# 1025
# Pause for 1 second ....
# 1050
# Pause for 1 second ....
# 1075
# Pause for 1 second ....
# 1100
# Pause for 1 second ....
# 1125
# Pause for 1 second ....
# 1150
# Pause for 1 second ....
# 1175
# Pause for 1 second ....
# 1200
# Pause for 1 second ....
# 1225
# Pause for 1 second ....
# 1250
# Pause for 1 second ....
# 1275
# Pause for 1 second ....
# 1300
# Pause for 1 second ....
# 1325
# Pause for 1 second ....
# 1350
# Pause for 1 second ....
# 1375
# Pause for 1 second ....
# 1400
# Pause for 1 second ....
# 1425
# Pause for 1 second ....
# 1450
# Pause for 1 second ....
# 1475
# Pause for 1 second ....
# 1500
# Pause for 1 second ....
# 1525
# Pause for 1 second ....
# 1550
# Pause for 1 second ....
# 1575
# Pause for 1 second ....
# 1600
# Pause for 1 second ....
# 1625
# Pause for 1 second ....
# 1650
# Pause for 1 second ....
# 1675
# Pause for 1 second ....
# 1700
# Pause for 1 second ....
# 1725
# Pause for 1 second ....
# 1750
# Pause for 1 second ....
# 1775
# Pause for 1 second ....
# 1800
# Pause for 1 second ....
# 1825
# Pause for 1 second ....
# 1850
# Pause for 1 second ....
# 1875
# Pause for 1 second ....
# 1900
# Pause for 1 second ....
# 1925
# Pause for 1 second ....
# 1950
# Pause for 1 second ....
# 1975
# Pause for 1 second ....
# 2000
# Pause for 1 second ....
# 2025
# Pause for 1 second ....
# 2050
# Pause for 1 second ....
# 2075
# Pause for 1 second ....
# 2100
# Pause for 1 second ....
# 2125
# Pause for 1 second ....
# 2150
# Pause for 1 second ....
# 2175
# Pause for 1 second ....
# 2200
# Pause for 1 second ....
# 2225
# Pause for 1 second ....
# 2250
# Pause for 1 second ....
# 2275
# Pause for 1 second ....
# 2300
# Pause for 1 second ....
# 2325
# Pause for 1 second ....
# 2350
# Pause for 1 second ....
# 2375
# Pause for 1 second ....
# 2400
# Pause for 1 second ....
# 2425
# Pause for 1 second ....
# 2450
# Pause for 1 second ....
# 2475
# Pause for 1 second ....
# 2500
# Pause for 1 second ....
# 2525
# Pause for 1 second ....
# 2550
# Pause for 1 second ....
# 2575
# Pause for 1 second ....
# 2600
# Pause for 1 second ....
# 2625
# Pause for 1 second ....
# 2650
# Pause for 1 second ....
# 2675
# Pause for 1 second ....
# 2700
# Pause for 1 second ....
# 2725
# Pause for 1 second ....
# 2750
# Pause for 1 second ....
# 2775
# Pause for 1 second ....
# 2800
# Pause for 1 second ....
# 2825
# Pause for 1 second ....
# 2850
# Pause for 1 second ....
# 2875
# Pause for 1 second ....
# 2900
# Pause for 1 second ....
# 2925
# Pause for 1 second ....
# 2950
# Pause for 1 second ....
# 2975
# Pause for 1 second ....
# 3000
# Pause for 1 second ....
# 3025
# Pause for 1 second ....
# 3050
# Pause for 1 second ....
# 3075
# Pause for 1 second ....
# 3100
# Pause for 1 second ....
# 3125
# Pause for 1 second ....
# 3150
# Pause for 1 second ....
# 3175
# Pause for 1 second ....
# 3200
# Pause for 1 second ....
# 3225
# Pause for 1 second ....
# 3250
# Pause for 1 second ....
# 3275
# Pause for 1 second ....
# 3300
# Pause for 1 second ....
# 3325
# Pause for 1 second ....
# 3350
# Pause for 1 second ....
# 3375
# Pause for 1 second ....
# 3400
# Pause for 1 second ....
# 3425
# Pause for 1 second ....
# 3450
# Pause for 1 second ....
# 3475
# Pause for 1 second ....
# 3500
# Pause for 1 second ....
# 3525
# Pause for 1 second ....
# 3550
# Pause for 1 second ....
# 3575
# Pause for 1 second ....
# 3600
# Pause for 1 second ....
# 3625
# Pause for 1 second ....
# 3650
# Pause for 1 second ....
# 3675
# Pause for 1 second ....
# 3700
# Pause for 1 second ....
# 3725
# Pause for 1 second ....
# 3750
# Pause for 1 second ....
# 3775
# Pause for 1 second ....
# 3800
# Pause for 1 second ....
# 3825
# Pause for 1 second ....
# 3850
# Pause for 1 second ....
# 3875
# Pause for 1 second ....
# 3900
# Pause for 1 second ....
# 3925
# Pause for 1 second ....
# 3950
# Pause for 1 second ....
# 3975
# Pause for 1 second ....
# 4000
# Pause for 1 second ....
# 4025
# Pause for 1 second ....
# 4050
# Pause for 1 second ....
# 4075
# Pause for 1 second ....
# 4100
# Pause for 1 second ....
# 4125
# Pause for 1 second ....
# 4150
# Pause for 1 second ....
# 4175
# Pause for 1 second ....
# 4200
# Pause for 1 second ....
# 4225
# Pause for 1 second ....
# 4250
# Pause for 1 second ....
# 4275
# Pause for 1 second ....
# 4300
# Pause for 1 second ....
# 4325
# Pause for 1 second ....
# 4350
# Pause for 1 second ....
# 4375
# Pause for 1 second ....
# 4400
# Pause for 1 second ....
# 4425
# Pause for 1 second ....
# 4450
# Pause for 1 second ....
# 4475
# Pause for 1 second ....
# 4500
# Pause for 1 second ....
# 4525
# Pause for 1 second ....
# 4550
# Pause for 1 second ....
# 4575
# Pause for 1 second ....
# 4600
# Pause for 1 second ....
# 4625
# Pause for 1 second ....
# 4650
# Pause for 1 second ....
# 4675
# Pause for 1 second ....
# 4700
# Pause for 1 second ....
# 4725
# Pause for 1 second ....
# 4750
# Pause for 1 second ....
# 4775
# Pause for 1 second ....
# 4800
# Pause for 1 second ....
# 4825
# Pause for 1 second ....
# 4850
# Pause for 1 second ....
# 4875
# Pause for 1 second ....
# 4900
# Pause for 1 second ....
# 4925
# Pause for 1 second ....
# 4950
# Pause for 1 second ....
# 4975
# Pause for 1 second ....
# 5000
# Pause for 1 second ....
# 5025
# Pause for 1 second ....
# 5050
# Pause for 1 second ....
# 5075
# Pause for 1 second ....
# 5100
# Pause for 1 second ....
# 5125
# Pause for 1 second ....
# 5150
# Pause for 1 second ....
# 5175
# Pause for 1 second ....
# 5200
# Pause for 1 second ....
# 5225
# Pause for 1 second ....
# done!
